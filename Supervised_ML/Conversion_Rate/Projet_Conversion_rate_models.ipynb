# %% [markdown]
# <img src="data:image/png;base64,..." alt="DSW LOGO" />

# %% [markdown]
# # Challenge : predict conversions 🏆🏆
# In this project, you will participate to a machine learning competition like the ones that are organized by https://www.kaggle.com/. You will be able to work with jupyter notebooks as usual, but in the end you'll have to submit your model's predictions to your teacher/TA, so your model's performances will be evaluated in an independent way. The scores achieved by the different teams will be stored into a leaderboard 🏅🏅
#
# ## Description of a machine learning challenge 🚴🚴
# - In machine learning challenges, the dataset is always separated into to files :
#     - *data_train.csv* contains **labelled data**, which means there are both X (explanatory variables) and Y (the target to be predicted). You will use this file to train your model as usual : make the train/test split, preprocessings, assess performances, try different models, fine-tune hyperparameters etc...
#     - *data_test.csv* contains "new" examples that have not be used to train the model, in the same format as in *data_train.csv* but it is **unlabeled**, which means the target Y has been removed from the file. Once you've trained a model, you will use *data_test.csv* to make some predictions that you will send to the organizing team. They will then be able to assess the performances of your model in an independent way, by preventing cheating 🤸
# - Your model's predictions will be compared to the true labels and releases a leaderboard where the scores of all the teams around the world are stored
# - All the participants are informed about the metric that will be used to assess the scores. You have to make sure you're using the same metric to evaluate your train/test performances !
#
# ## Company's Description 📇
# www.datascienceweekly.org is a famous newsletter curated by independent data scientists. Anyone can register his/her e-mail address on this website to receive weekly news about data science and its applications !
#
# ## Project 🚧
# The data scientists who created the newsletter would like to understand better the behaviour of the users visiting their website. They would like to know if it's possible to build a model that predicts if a given user will subscribe to the newsletter, by using just a few information about the user. They would like to analyze the parameters of the model to highlight features that are important to explain the behaviour of the users, and maybe discover a new lever for action to improve the newsletter's conversion rate.
#
# They designed a competition aiming at building a model that allows to predict the *conversions* (i.e. when a user will subscribe to the newsletter). To do so, they open-sourced a dataset containing some data about the traffic on their website. To assess the rankings of the different competing teams, they decided to use the **f1-score**.
#
# ## Goals 🎯
# The project can be cut into four steps :
# - Part 1 : make an EDA and the preprocessings and train a baseline model with the file *data_train.csv*
# - Part 2 : improve your model's f1-score on your test set (you can try feature engineering, feature selection, regularization, non-linear models, hyperparameter optimization by grid search, etc...)
# - Part 3 : Once you're satisfied with your model's score, you can use it to make some predictions with the file *data_test.csv*. You will have to dump the predictions into a .csv file that will be sent to Kaggle (actually, to your teacher/TA 🤓). You can make as many submissions as you want, feel free to try different models !
# - Part 4 : Take some time to analyze your best model's parameters. Are there any lever for action that would help to improve the newsletter's conversion rate ? What recommendations would you make to the team ?
#
# ## Deliverable 📬
# To complete this project, your team should:
# - Create some relevant figures for EDA
# - Train at least one model that predicts the conversions and evaluate its performances (f1, confusion matrices)
# - Make at least one submission to the leaderboard
# - Analyze your best model's parameters and try to make some recommendations to improve the conversion rate in the future

# %% [markdown]
# # Preparation of the datasets

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, classification_report, ConfusionMatrixDisplay, roc_curve, RocCurveDisplay
from sklearn.feature_selection import SequentialFeatureSelector

from imblearn.over_sampling import SMOTENC
from collections import Counter

import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Dataset

# %%
# see Notebook "EDA" for the reasoning behind this choice

data = pd.read_csv('conversion_data_train.csv')
data = data.loc[data['age']<80,:]
data.head()
# Out:
#    country  age  new_user  source  total_pages_visited  converted
# 0    China   22         1  Direct                    2          0
# 1       UK   21         1     Ads                    3          0
# 2  Germany   20         0     Seo                   14          1
# 3       US   23         1     Seo                    3          0
# 4       US   28         1  Direct                    3          0

# %% [markdown]
# ## Creation of train and test sets

# %%
features_list = list(data.columns)
features_list.remove('converted')
target_variable = 'converted'

X = data.loc[:, features_list]
Y = data.loc[:, target_variable]

print("Dividing into train and test sets...")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, stratify = Y, random_state=0)

X_train['country'].astype("category")
X_train['new_user'].astype("category")
X_train['source'].astype("category")
X_test['country'].astype("category")
X_test['new_user'].astype("category")
X_test['source'].astype("category")

print("...Done.")
# Out:
# Dividing into train and test sets...
# ...Done.

# %% [markdown]
# ## Preprocessing

# %%
print("Encoding categorical features and standardizing numerical features...")

numeric_features = features_list.copy()
numeric_features.remove("country")
numeric_features.remove("new_user")
numeric_features.remove("source")
categorical_features = ["country", "new_user", "source"]

numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(drop="first")

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

print("...Done")
# Out:
# Encoding categorical features and standardizing numerical features...
# ...Done

# %% [markdown]
# # Models

# %% [markdown]
# ## Without feature engineering

# %% [markdown]
# ### Baseline

# %%
# The feature with the most effect on the conversion is 'total_pages_visited' (see Notebook "EDA")

features_list_baseline = ['total_pages_visited']
X_baseline = data.loc[:, features_list_baseline]
X_train_baseline, X_test_baseline, Y_train_baseline, Y_test_baseline = train_test_split(X_baseline, Y, test_size=0.1, stratify = Y, random_state=0)
numeric_transformer_baseline = StandardScaler()
X_train_baseline = numeric_transformer_baseline.fit_transform(X_train_baseline)
X_test_baseline = numeric_transformer_baseline.transform(X_test_baseline)

# %%
# Simple Logistic Regression

baseline = LogisticRegression()
baseline.fit(X_train_baseline, Y_train_baseline)
Y_train_pred_baseline = baseline.predict(X_train_baseline)
Y_test_pred_baseline = baseline.predict(X_test_baseline)
print("f1-score on train set : ", f1_score(Y_train_baseline, Y_train_pred_baseline))
print("f1-score on test set : ", f1_score(Y_test_baseline, Y_test_pred_baseline))
# Out:
# f1-score on train set :  0.6950136373172948
# f1-score on test set :  0.6961394769613949

# %% [markdown]
# ### Other models with grid search

# %%
# Logistic Regression with class weights and L2

logreg = LogisticRegressionCV(penalty='l2') 
params = {
    'Cs': [5, 10, 15], 
    'class_weight': [
        None,
        {0: 1, 1: 1.3},
        {0: 1, 1: 1.5},
        'balanced'
    ]
}
gridsearch = GridSearchCV(logreg, scoring="precision", param_grid = params, cv = 3, verbose = 2)
gridsearch.fit(X_train, Y_train)

print("Best Parameters:", gridsearch.best_params_)
print("Best Score:", gridsearch.best_score_)

Y_train_pred = gridsearch.predict(X_train)
Y_test_pred = gridsearch.predict(X_test)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END ............................Cs=5, class_weight=None; total time=   2.6s
# [CV] END ............................Cs=5, class_weight=None; total time=   2.6s
# [CV] END ............................Cs=5, class_weight=None; total time=   2.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   2.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   2.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   2.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   2.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   2.9s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   2.9s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   2.8s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   3.0s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   3.1s
# [CV] END ...........................Cs=10, class_weight=None; total time=   4.7s
# [CV] END ...........................Cs=10, class_weight=None; total time=   4.8s
# [CV] END ...........................Cs=10, class_weight=None; total time=   4.6s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=   4.8s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=   4.6s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=   5.0s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=   4.8s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=   5.0s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=   4.5s
# [CV] END .......................Cs=10, class_weight=balanced; total time=   5.1s
# [CV] END .......................Cs=10, class_weight=balanced; total time=   4.9s
# [CV] END .......................Cs=10, class_weight=balanced; total time=   5.3s
# [CV] END ...........................Cs=15, class_weight=None; total time=   6.8s
# [CV] END ...........................Cs=15, class_weight=None; total time=   6.2s
# [CV] END ...........................Cs=15, class_weight=None; total time=   6.5s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=   6.9s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=   6.7s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=   6.4s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=   6.7s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=   6.1s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=   6.4s
# [CV] END .......................Cs=15, class_weight=balanced; total time=   6.8s
# [CV] END .......................Cs=15, class_weight=balanced; total time=   7.0s
# [CV] END .......................Cs=15, class_weight=balanced; total time=   6.8s
# Best Parameters: {'Cs': 10, 'class_weight': None}
# Best Score: 0.8543719753210537
# f1-score on train set :  0.7627414163090129
# f1-score on test set :  0.7711711711711712

# %%
# Random forest with class weights

RFC = RandomForestClassifier()
params = {
    'max_depth': [10, 20],
    'min_samples_leaf': [10, 20, 30],
    'min_samples_split': [10, 20, 30],
    'n_estimators': [40, 50],
    'class_weight': [
        None,
        {0: 1, 1: 1.3},
        {0: 1, 1: 1.5}
    ]
}
gridsearch = GridSearchCV(RFC, param_grid = params, scoring='precision', cv = 3, verbose = 2)
gridsearch.fit(X_train, Y_train)

print("Best Parameters:", gridsearch.best_params_)
print("Best Score:", gridsearch.best_score_)

Y_train_pred = gridsearch.predict(X_train)
Y_test_pred = gridsearch.predict(X_test)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   3.0s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   3.0s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.4s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.3}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.4s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.2s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.4s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.3s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=10, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.4s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=10, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=10, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   3.0s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=20, min_samples_split=30, n_estimators=50; total time=   3.7s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=10, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.5s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=20, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.9s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=40; total time=   2.8s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.6s
# [CV] END class_weight={0: 1, 1: 1.5}, max_depth=20, min_samples_leaf=30, min_samples_split=30, n_estimators=50; total time=   3.6s
# Best Parameters: {'class_weight': None, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 20, 'n_estimators': 50}
# Best Score: 0.8558571127511062
# f1-score on train set :  0.7712330605125453
# f1-score on test set :  0.7584134615384615

# %%
# XGBoost with class weights

XGBC = XGBClassifier()
weight_ratio = float(len(Y_train[Y_train == 0]))/float(len(Y_train[Y_train == 1]))
params = {
    "max_depth": [2, 4, 6, 8],
    "min_child_weight": [2, 4, 6, 8, 10],
    "n_estimators": [10, 25, 50],
    'scale_pos_weight': [weight_ratio, 1]
}
gridsearch = GridSearchCV(XGBC, param_grid = params, scoring='precision', cv = 3, verbose = 2)
gridsearch.fit(X_train, Y_train)

print("Best Parameters:", gridsearch.best_params_)
print("Best Score:", gridsearch.best_score_)

Y_train_pred = gridsearch.predict(X_train)
Y_test_pred = gridsearch.predict(X_test)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=2, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   1.0s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   2.0s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=2, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=2, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.6s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   1.6s
# [CV] END max_depth=4, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.1s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.3s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.3s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   1.4s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   1.3s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=4, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.5s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.7s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   1.8s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   1.3s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   1.0s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   1.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.6s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.3s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   1.6s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   1.2s
# [CV] END max_depth=6, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.8s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.7s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.6s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   1.0s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=2, n_estimators=50, scale_pos_weight=1; total time=   1.4s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=25, scale_pos_weight=1; total time=   1.2s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   2.0s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   1.8s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=4, n_estimators=50, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.3s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.4s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=25, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.9s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   1.5s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=6, n_estimators=50, scale_pos_weight=1; total time=   1.9s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=10, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.7s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   1.4s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=8, n_estimators=50, scale_pos_weight=1; total time=   1.1s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.4s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.9s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=30.00726392251816; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.3s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=10, scale_pos_weight=1; total time=   0.2s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.0s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.6s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=25, scale_pos_weight=1; total time=   0.5s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.2s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   1.3s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=30.00726392251816; total time=   0.7s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   0.8s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   1.4s
# [CV] END max_depth=8, min_child_weight=10, n_estimators=50, scale_pos_weight=1; total time=   1.2s
# Best Parameters: {'max_depth': 2, 'min_child_weight': 8, 'n_estimators': 25, 'scale_pos_weight': 1}
# Best Score: 0.8567138326646048
# f1-score on train set :  0.7518551296888829
# f1-score on test set :  0.754694124772865

# %% [markdown]
# ### Voting on the best models

# %%
voting = VotingClassifier(
    estimators=[("logistic", LogisticRegressionCV(Cs=10, penalty='l2')), 
                 ("tree", RandomForestClassifier(max_depth=10, min_samples_leaf=10, 
                    min_samples_split=20, n_estimators=50)), 
                 ("XGboosting", XGBClassifier(max_depth=2, min_child_weight=8, n_estimators=25))],
    voting="soft",
)
voting.fit(X_train, Y_train)

Y_train_pred = voting.predict(X_train)
Y_test_pred = voting.predict(X_test)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# f1-score on train set :  0.7636805837049047
# f1-score on test set :  0.7584541062801932

# %% [markdown]
# ## Best model with feature engineering

# %%
data_feateng = data.copy()

data_feateng['Age/Pages'] = data_feateng['age'] / data_feateng['total_pages_visited']
data_feateng['AgexNew'] = data_feateng['age'] * data_feateng['new_user'].replace({0:0.5, 1:1})

data_feateng["log_total_pages_visited"] = np.log(data_feateng["total_pages_visited"])   
data_feateng["sqrt_total_pages_visited"] = np.sqrt(data_feateng["total_pages_visited"])   
data_feateng["sq_total_pages_visited"] = data_feateng["total_pages_visited"] ** 2
data_feateng["sq3_total_pages_visited"] = data_feateng["total_pages_visited"] ** 3
data_feateng["sq4_total_pages_visited"] = data_feateng["total_pages_visited"] ** 4
data_feateng["inv_total_pages_visited"] = 1 / data_feateng["total_pages_visited"]

data_feateng["log_age"] = np.log(data_feateng["age"])   
data_feateng["sqrt_age"] = np.sqrt(data_feateng["age"])   
data_feateng["sq_age"] = data_feateng["age"] ** 2
data_feateng["sq3_age"] = data_feateng["age"] ** 3
data_feateng["sq4_age"] = data_feateng["age"] ** 4
data_feateng["inv_age"] = 1 / data_feateng["age"]

data_feateng.head()
# Out:
#    country  age  new_user  source  total_pages_visited  converted  Age/Pages  \
# 0    China   22         1  Direct                    2          0  11.000000
# 1       UK   21         1     Ads                    3          0   7.000000
# 2  Germany   20         0     Seo                   14          1   1.428571
# 3       US   23         1     Seo                    3          0   7.666667
# 4       US   28         1  Direct                    3          0   9.333333
#
#    AgexNew  log_total_pages_visited  sqrt_total_pages_visited  \
# 0     22.0                 0.693147                  1.414214
# 1     21.0                 1.098612                  1.732051
# 2     10.0                 2.639057                  3.741657
# 3     23.0                 1.098612                  1.732051
# 4     28.0                 1.098612                  1.732051
#
#    sq_total_pages_visited  sq3_total_pages_visited  sq4_total_pages_visited  \
# 0                       4                        8                       16
# 1                       9                       27                       81
# 2                     196                     2744                    38416
# 3                       9                       27                       81
# 4                       9                       27                       81
#
#    inv_total_pages_visited   log_age  sqrt_age  sq_age  sq3_age  sq4_age  \
# 0                 0.500000  3.091042  4.690416     484    10648   234256
# 1                 0.333333  3.044522  4.582576     441     9261   194481
# 2                 0.071429  2.995732  4.472136     400     8000   160000
# 3                 0.333333  3.135494  4.795832     529    12167   279841
# 4                 0.333333  3.332205  5.291503     784    21952   614656
#
#     inv_age
# 0  0.045455
# 1  0.047619
# 2  0.050000
# 3  0.043478
# 4  0.035714

# %%
features_list_feateng = list(data_feateng.columns)
features_list_feateng.remove('converted')
X_feateng = data_feateng.loc[:, features_list_feateng]
Y_feateng = data_feateng.loc[:, target_variable]
X_train_feateng, X_test_feateng, Y_train_feateng, Y_test_feateng = train_test_split(X_feateng, Y_feateng, test_size=0.1, 
                                                                                    stratify = Y_feateng, random_state=0)
X_train_feateng['country'].astype("category")
X_train_feateng['new_user'].astype("category")
X_train_feateng['source'].astype("category")
X_test_feateng['country'].astype("category")
X_test_feateng['new_user'].astype("category")
X_test_feateng['source'].astype("category")

numeric_features_feateng = features_list_feateng
numeric_features_feateng.remove("country")
numeric_features_feateng.remove("new_user")
numeric_features_feateng.remove("source")
preprocessor_feateng = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features_feateng),
        ("cat", categorical_transformer, categorical_features),
    ]
)
X_train_feateng = preprocessor_feateng.fit_transform(X_train_feateng)
X_test_feateng = preprocessor_feateng.transform(X_test_feateng)

# %%
classifier = LogisticRegression()
feature_selector =  SequentialFeatureSelector(classifier, n_features_to_select = 10) 
feature_selector.fit(X_train_feateng, Y_train)

column_names = []
for name, step, features_l in preprocessor_feateng.transformers_: 
    if name == 'num': 
        features = features_l 
    else: 
        features = step.get_feature_names_out() 
    column_names.extend(features) 

print("According to the forward selection algorithm, the following features should be kept: ")
for i in range(len(feature_selector.support_)):
    if feature_selector.support_[i] == True:
        print(column_names[i])
# Out:
# According to the forward selection algorithm, the following features should be kept:
# total_pages_visited
# Age/Pages
# AgexNew
# sqrt_total_pages_visited
# sq_age
# country_Germany
# country_UK
# country_US
# new_user_1
# source_Seo

# %%
data_feateng = data.copy()

data_feateng['Age/Pages'] = data_feateng['age'] / data_feateng['total_pages_visited']
data_feateng['AgexNew'] = data_feateng['age'] * data_feateng['new_user'].replace({0:0.5, 1:1})
data_feateng["sqrt_total_pages_visited"] = np.sqrt(data_feateng["total_pages_visited"])    
data_feateng["sq_age"] = data_feateng["age"] ** 2

features_list_feateng = list(data_feateng.columns)
features_list_feateng.remove('converted')
X_feateng = data_feateng.loc[:, features_list_feateng]
Y_feateng = data_feateng.loc[:, target_variable]
X_train_feateng, X_test_feateng, Y_train_feateng, Y_test_feateng = train_test_split(X_feateng, Y_feateng, test_size=0.1, 
                                                                                    stratify = Y_feateng, random_state=0)
X_train_feateng['country'].astype("category")
X_train_feateng['new_user'].astype("category")
X_train_feateng['source'].astype("category")
X_test_feateng['country'].astype("category")
X_test_feateng['new_user'].astype("category")
X_test_feateng['source'].astype("category")

numeric_features_feateng = features_list_feateng
numeric_features_feateng.remove("country")
numeric_features_feateng.remove("new_user")
numeric_features_feateng.remove("source")
preprocessor_feateng = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features_feateng),
        ("cat", categorical_transformer, categorical_features),
    ]
)
X_train_feateng = preprocessor_feateng.fit_transform(X_train_feateng)
X_test_feateng = preprocessor_feateng.transform(X_test_feateng)

# %%
params = {
    'Cs': [5, 10, 15], 
    'class_weight': [
        None,
        {0: 1, 1: 1.3},
        {0: 1, 1: 1.5},
        'balanced'
    ]
}
gridsearch = GridSearchCV(logreg, param_grid = params, scoring='precision', cv = 3, verbose = 2)
gridsearch.fit(X_train_feateng, Y_train)

print("Best Parameters:", gridsearch.best_params_)
print("Best Score:", gridsearch.best_score_)

Y_train_pred = gridsearch.predict(X_train_feateng)
Y_test_pred = gridsearch.predict(X_test_feateng)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END ............................Cs=5, class_weight=None; total time=   6.6s
# [CV] END ............................Cs=5, class_weight=None; total time=   6.6s
# [CV] END ............................Cs=5, class_weight=None; total time=   6.8s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   7.0s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   6.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.3}; total time=   7.1s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   6.7s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   7.1s
# [CV] END ..................Cs=5, class_weight={0: 1, 1: 1.5}; total time=   6.3s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   7.2s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   6.9s
# [CV] END ........................Cs=5, class_weight=balanced; total time=   7.0s
# [CV] END ...........................Cs=10, class_weight=None; total time=  10.9s
# [CV] END ...........................Cs=10, class_weight=None; total time=   9.8s
# [CV] END ...........................Cs=10, class_weight=None; total time=   9.9s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=  10.7s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=  10.1s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.3}; total time=   9.8s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=  10.1s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=  10.4s
# [CV] END .................Cs=10, class_weight={0: 1, 1: 1.5}; total time=   9.9s
# [CV] END .......................Cs=10, class_weight=balanced; total time=  10.6s
# [CV] END .......................Cs=10, class_weight=balanced; total time=  10.5s
# [CV] END .......................Cs=10, class_weight=balanced; total time=  10.8s
# [CV] END ...........................Cs=15, class_weight=None; total time=  13.7s
# [CV] END ...........................Cs=15, class_weight=None; total time=  12.5s
# [CV] END ...........................Cs=15, class_weight=None; total time=  13.1s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=  14.3s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=  13.1s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.3}; total time=  13.7s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=  14.2s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=  13.4s
# [CV] END .................Cs=15, class_weight={0: 1, 1: 1.5}; total time=  14.0s
# [CV] END .......................Cs=15, class_weight=balanced; total time=  14.0s
# [CV] END .......................Cs=15, class_weight=balanced; total time=  14.9s
# [CV] END .......................Cs=15, class_weight=balanced; total time=  14.1s
# Best Parameters: {'Cs': 10, 'class_weight': None}
# Best Score: 0.8546872262666075
# f1-score on train set :  0.7624974904637623
# f1-score on test set :  0.7697841726618704

# %% [markdown]
# Conclusion : les feature engineering ne semblent pas améliorer le modèle

# %% [markdown]
# ## Using SMOTE to compensate for imbalanced data

# %%
sm = SMOTENC(categorical_features=[2,3,4,5,6,7], sampling_strategy=0.05)

X_train_resampled, Y_train_resampled = sm.fit_resample(X_train, Y_train)

print('Original dataset shape:', Counter(Y_train))
print('Resampled dataset shape:', Counter(Y_train_resampled))

xgbc_smote = XGBClassifier()
params = {
    "max_depth": [2, 4, 6, 8, 10],
    "min_child_weight": [2, 4, 6, 8, 10],
    "n_estimators": [10, 25, 50, 75, 100]
}
gridsearch = GridSearchCV(xgbc_smote, param_grid = params, scoring='f1', cv = 3, verbose = 2)
gridsearch.fit(X_train_resampled, Y_train_resampled, eval_set = [(X_test, Y_test)])

print("Best Parameters:", gridsearch.best_params_)
print("Best Score:", gridsearch.best_score_)

Y_train_pred = gridsearch.predict(X_train)
Y_test_pred = gridsearch.predict(X_test)

print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
# Out:
# Original dataset shape: Counter({0: 247860, 1: 8260})
# Resampled dataset shape: Counter({0: 247860, 1: 12393})
# Fitting 3 folds for each of 125 candidates, totalling 375 fits
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=10; total time=   0.6s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=10; total time=   0.5s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=10; total time=   0.5s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=25; total time=   2.5s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=25; total time=   0.8s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04471
# [24]	validation_0-logloss:0.04449
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=25; total time=   1.3s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04291
# [42]	validation_0-logloss:0.04287
# [43]	validation_0-logloss:0.04286
# [44]	validation_0-logloss:0.04281
# [45]	validation_0-logloss:0.04272
# [46]	validation_0-logloss:0.04273
# [47]	validation_0-logloss:0.04270
# [48]	validation_0-logloss:0.04268
# [49]	validation_0-logloss:0.04267
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=50; total time=   1.0s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [25]	validation_0-logloss:0.04439
# [26]	validation_0-logloss:0.04424
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04397
# [29]	validation_0-logloss:0.04388
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04373
# [32]	validation_0-logloss:0.04355
# [33]	validation_0-logloss:0.04353
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04341
# [36]	validation_0-logloss:0.04336
# [37]	validation_0-logloss:0.04331
# [38]	validation_0-logloss:0.04317
# [39]	validation_0-logloss:0.04316
# [40]	validation_0-logloss:0.04312
# [41]	validation_0-logloss:0.04308
# [42]	validation_0-logloss:0.04304
# [43]	validation_0-logloss:0.04294
# [44]	validation_0-logloss:0.04295
# [45]	validation_0-logloss:0.04286
# [46]	validation_0-logloss:0.04285
# [47]	validation_0-logloss:0.04285
# [48]	validation_0-logloss:0.04282
# [49]	validation_0-logloss:0.04279
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=50; total time=   2.2s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04471
# [24]	validation_0-logloss:0.04449
# [25]	validation_0-logloss:0.04440
# [26]	validation_0-logloss:0.04430
# [27]	validation_0-logloss:0.04416
# [28]	validation_0-logloss:0.04388
# [29]	validation_0-logloss:0.04382
# [30]	validation_0-logloss:0.04373
# [31]	validation_0-logloss:0.04364
# [32]	validation_0-logloss:0.04356
# [33]	validation_0-logloss:0.04348
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04327
# [36]	validation_0-logloss:0.04320
# [37]	validation_0-logloss:0.04316
# [38]	validation_0-logloss:0.04314
# [39]	validation_0-logloss:0.04302
# [40]	validation_0-logloss:0.04300
# [41]	validation_0-logloss:0.04287
# [42]	validation_0-logloss:0.04284
# [43]	validation_0-logloss:0.04279
# [44]	validation_0-logloss:0.04276
# [45]	validation_0-logloss:0.04276
# [46]	validation_0-logloss:0.04266
# [47]	validation_0-logloss:0.04264
# [48]	validation_0-logloss:0.04262
# [49]	validation_0-logloss:0.04259
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=50; total time=   1.6s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04291
# [42]	validation_0-logloss:0.04287
# [43]	validation_0-logloss:0.04286
# [44]	validation_0-logloss:0.04281
# [45]	validation_0-logloss:0.04272
# [46]	validation_0-logloss:0.04273
# [47]	validation_0-logloss:0.04270
# [48]	validation_0-logloss:0.04268
# [49]	validation_0-logloss:0.04267
# [50]	validation_0-logloss:0.04265
# [51]	validation_0-logloss:0.04259
# [52]	validation_0-logloss:0.04259
# [53]	validation_0-logloss:0.04255
# [54]	validation_0-logloss:0.04255
# [55]	validation_0-logloss:0.04255
# [56]	validation_0-logloss:0.04255
# [57]	validation_0-logloss:0.04254
# [58]	validation_0-logloss:0.04249
# [59]	validation_0-logloss:0.04250
# [60]	validation_0-logloss:0.04246
# [61]	validation_0-logloss:0.04245
# [62]	validation_0-logloss:0.04243
# [63]	validation_0-logloss:0.04243
# [64]	validation_0-logloss:0.04242
# [65]	validation_0-logloss:0.04242
# [66]	validation_0-logloss:0.04243
# [67]	validation_0-logloss:0.04240
# [68]	validation_0-logloss:0.04241
# [69]	validation_0-logloss:0.04240
# [70]	validation_0-logloss:0.04239
# [71]	validation_0-logloss:0.04238
# [72]	validation_0-logloss:0.04237
# [73]	validation_0-logloss:0.04237
# [74]	validation_0-logloss:0.04237
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=75; total time=   2.0s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [25]	validation_0-logloss:0.04439
# [26]	validation_0-logloss:0.04424
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04397
# [29]	validation_0-logloss:0.04388
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04373
# [32]	validation_0-logloss:0.04355
# [33]	validation_0-logloss:0.04353
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04341
# [36]	validation_0-logloss:0.04336
# [37]	validation_0-logloss:0.04331
# [38]	validation_0-logloss:0.04317
# [39]	validation_0-logloss:0.04316
# [40]	validation_0-logloss:0.04312
# [41]	validation_0-logloss:0.04308
# [42]	validation_0-logloss:0.04304
# [43]	validation_0-logloss:0.04294
# [44]	validation_0-logloss:0.04295
# [45]	validation_0-logloss:0.04286
# [46]	validation_0-logloss:0.04285
# [47]	validation_0-logloss:0.04285
# [48]	validation_0-logloss:0.04282
# [49]	validation_0-logloss:0.04279
# [50]	validation_0-logloss:0.04279
# [51]	validation_0-logloss:0.04277
# [52]	validation_0-logloss:0.04277
# [53]	validation_0-logloss:0.04278
# [54]	validation_0-logloss:0.04270
# [55]	validation_0-logloss:0.04268
# [56]	validation_0-logloss:0.04267
# [57]	validation_0-logloss:0.04265
# [58]	validation_0-logloss:0.04265
# [59]	validation_0-logloss:0.04265
# [60]	validation_0-logloss:0.04265
# [61]	validation_0-logloss:0.04260
# [62]	validation_0-logloss:0.04261
# [63]	validation_0-logloss:0.04260
# [64]	validation_0-logloss:0.04256
# [65]	validation_0-logloss:0.04257
# [66]	validation_0-logloss:0.04253
# [67]	validation_0-logloss:0.04253
# [68]	validation_0-logloss:0.04253
# [69]	validation_0-logloss:0.04254
# [70]	validation_0-logloss:0.04253
# [71]	validation_0-logloss:0.04252
# [72]	validation_0-logloss:0.04250
# [73]	validation_0-logloss:0.04250
# [74]	validation_0-logloss:0.04250
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=75; total time=   3.3s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04471
# [24]	validation_0-logloss:0.04449
# [25]	validation_0-logloss:0.04440
# [26]	validation_0-logloss:0.04430
# [27]	validation_0-logloss:0.04416
# [28]	validation_0-logloss:0.04388
# [29]	validation_0-logloss:0.04382
# [30]	validation_0-logloss:0.04373
# [31]	validation_0-logloss:0.04364
# [32]	validation_0-logloss:0.04356
# [33]	validation_0-logloss:0.04348
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04327
# [36]	validation_0-logloss:0.04320
# [37]	validation_0-logloss:0.04316
# [38]	validation_0-logloss:0.04314
# [39]	validation_0-logloss:0.04302
# [40]	validation_0-logloss:0.04300
# [41]	validation_0-logloss:0.04287
# [42]	validation_0-logloss:0.04284
# [43]	validation_0-logloss:0.04279
# [44]	validation_0-logloss:0.04276
# [45]	validation_0-logloss:0.04276
# [46]	validation_0-logloss:0.04266
# [47]	validation_0-logloss:0.04264
# [48]	validation_0-logloss:0.04262
# [49]	validation_0-logloss:0.04259
# [50]	validation_0-logloss:0.04260
# [51]	validation_0-logloss:0.04252
# [52]	validation_0-logloss:0.04250
# [53]	validation_0-logloss:0.04252
# [54]	validation_0-logloss:0.04249
# [55]	validation_0-logloss:0.04248
# [56]	validation_0-logloss:0.04248
# [57]	validation_0-logloss:0.04242
# [58]	validation_0-logloss:0.04242
# [59]	validation_0-logloss:0.04242
# [60]	validation_0-logloss:0.04242
# [61]	validation_0-logloss:0.04241
# [62]	validation_0-logloss:0.04242
# [63]	validation_0-logloss:0.04237
# [64]	validation_0-logloss:0.04235
# [65]	validation_0-logloss:0.04236
# [66]	validation_0-logloss:0.04236
# [67]	validation_0-logloss:0.04232
# [68]	validation_0-logloss:0.04231
# [69]	validation_0-logloss:0.04230
# [70]	validation_0-logloss:0.04231
# [71]	validation_0-logloss:0.04231
# [72]	validation_0-logloss:0.04232
# [73]	validation_0-logloss:0.04229
# [74]	validation_0-logloss:0.04230
# [CV] END ...max_depth=2, min_child_weight=2, n_estimators=75; total time=   1.9s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04291
# [42]	validation_0-logloss:0.04287
# [43]	validation_0-logloss:0.04286
# [44]	validation_0-logloss:0.04281
# [45]	validation_0-logloss:0.04272
# [46]	validation_0-logloss:0.04273
# [47]	validation_0-logloss:0.04270
# [48]	validation_0-logloss:0.04268
# [49]	validation_0-logloss:0.04267
# [50]	validation_0-logloss:0.04265
# [51]	validation_0-logloss:0.04259
# [52]	validation_0-logloss:0.04259
# [53]	validation_0-logloss:0.04255
# [54]	validation_0-logloss:0.04255
# [55]	validation_0-logloss:0.04255
# [56]	validation_0-logloss:0.04255
# [57]	validation_0-logloss:0.04254
# [58]	validation_0-logloss:0.04249
# [59]	validation_0-logloss:0.04250
# [60]	validation_0-logloss:0.04246
# [61]	validation_0-logloss:0.04245
# [62]	validation_0-logloss:0.04243
# [63]	validation_0-logloss:0.04243
# [64]	validation_0-logloss:0.04242
# [65]	validation_0-logloss:0.04242
# [66]	validation_0-logloss:0.04243
# [67]	validation_0-logloss:0.04240
# [68]	validation_0-logloss:0.04241
# [69]	validation_0-logloss:0.04240
# [70]	validation_0-logloss:0.04239
# [71]	validation_0-logloss:0.04238
# [72]	validation_0-logloss:0.04237
# [73]	validation_0-logloss:0.04237
# [74]	validation_0-logloss:0.04237
# [75]	validation_0-logloss:0.04235
# [76]	validation_0-logloss:0.04236
# [77]	validation_0-logloss:0.04234
# [78]	validation_0-logloss:0.04234
# [79]	validation_0-logloss:0.04234
# [80]	validation_0-logloss:0.04233
# [81]	validation_0-logloss:0.04232
# [82]	validation_0-logloss:0.04232
# [83]	validation_0-logloss:0.04230
# [84]	validation_0-logloss:0.04229
# [85]	validation_0-logloss:0.04227
# [86]	validation_0-logloss:0.04224
# [87]	validation_0-logloss:0.04223
# [88]	validation_0-logloss:0.04221
# [89]	validation_0-logloss:0.04222
# [90]	validation_0-logloss:0.04222
# [91]	validation_0-logloss:0.04223
# [92]	validation_0-logloss:0.04222
# [93]	validation_0-logloss:0.04222
# [94]	validation_0-logloss:0.04221
# [95]	validation_0-logloss:0.04221
# [96]	validation_0-logloss:0.04222
# [97]	validation_0-logloss:0.04219
# [98]	validation_0-logloss:0.04218
# [99]	validation_0-logloss:0.04217
# [CV] END ..max_depth=2, min_child_weight=2, n_estimators=100; total time=   3.2s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [25]	validation_0-logloss:0.04439
# [26]	validation_0-logloss:0.04424
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04397
# [29]	validation_0-logloss:0.04388
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04373
# [32]	validation_0-logloss:0.04355
# [33]	validation_0-logloss:0.04353
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04341
# [36]	validation_0-logloss:0.04336
# [37]	validation_0-logloss:0.04331
# [38]	validation_0-logloss:0.04317
# [39]	validation_0-logloss:0.04316
# [40]	validation_0-logloss:0.04312
# [41]	validation_0-logloss:0.04308
# [42]	validation_0-logloss:0.04304
# [43]	validation_0-logloss:0.04294
# [44]	validation_0-logloss:0.04295
# [45]	validation_0-logloss:0.04286
# [46]	validation_0-logloss:0.04285
# [47]	validation_0-logloss:0.04285
# [48]	validation_0-logloss:0.04282
# [49]	validation_0-logloss:0.04279
# [50]	validation_0-logloss:0.04279
# [51]	validation_0-logloss:0.04277
# [52]	validation_0-logloss:0.04277
# [53]	validation_0-logloss:0.04278
# [54]	validation_0-logloss:0.04270
# [55]	validation_0-logloss:0.04268
# [56]	validation_0-logloss:0.04267
# [57]	validation_0-logloss:0.04265
# [58]	validation_0-logloss:0.04265
# [59]	validation_0-logloss:0.04265
# [60]	validation_0-logloss:0.04265
# [61]	validation_0-logloss:0.04260
# [62]	validation_0-logloss:0.04261
# [63]	validation_0-logloss:0.04260
# [64]	validation_0-logloss:0.04256
# [65]	validation_0-logloss:0.04257
# [66]	validation_0-logloss:0.04253
# [67]	validation_0-logloss:0.04253
# [68]	validation_0-logloss:0.04253
# [69]	validation_0-logloss:0.04254
# [70]	validation_0-logloss:0.04253
# [71]	validation_0-logloss:0.04252
# [72]	validation_0-logloss:0.04250
# [73]	validation_0-logloss:0.04250
# [74]	validation_0-logloss:0.04250
# [75]	validation_0-logloss:0.04251
# [76]	validation_0-logloss:0.04248
# [77]	validation_0-logloss:0.04249
# [78]	validation_0-logloss:0.04247
# [79]	validation_0-logloss:0.04240
# [80]	validation_0-logloss:0.04239
# [81]	validation_0-logloss:0.04240
# [82]	validation_0-logloss:0.04241
# [83]	validation_0-logloss:0.04242
# [84]	validation_0-logloss:0.04240
# [85]	validation_0-logloss:0.04239
# [86]	validation_0-logloss:0.04239
# [87]	validation_0-logloss:0.04237
# [88]	validation_0-logloss:0.04238
# [89]	validation_0-logloss:0.04237
# [90]	validation_0-logloss:0.04238
# [91]	validation_0-logloss:0.04236
# [92]	validation_0-logloss:0.04236
# [93]	validation_0-logloss:0.04235
# [94]	validation_0-logloss:0.04234
# [95]	validation_0-logloss:0.04234
# [96]	validation_0-logloss:0.04233
# [97]	validation_0-logloss:0.04234
# [98]	validation_0-logloss:0.04230
# [99]	validation_0-logloss:0.04229
# [CV] END ..max_depth=2, min_child_weight=2, n_estimators=100; total time=   2.9s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04471
# [24]	validation_0-logloss:0.04449
# [25]	validation_0-logloss:0.04440
# [26]	validation_0-logloss:0.04430
# [27]	validation_0-logloss:0.04416
# [28]	validation_0-logloss:0.04388
# [29]	validation_0-logloss:0.04382
# [30]	validation_0-logloss:0.04373
# [31]	validation_0-logloss:0.04364
# [32]	validation_0-logloss:0.04356
# [33]	validation_0-logloss:0.04348
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04327
# [36]	validation_0-logloss:0.04320
# [37]	validation_0-logloss:0.04316
# [38]	validation_0-logloss:0.04314
# [39]	validation_0-logloss:0.04302
# [40]	validation_0-logloss:0.04300
# [41]	validation_0-logloss:0.04287
# [42]	validation_0-logloss:0.04284
# [43]	validation_0-logloss:0.04279
# [44]	validation_0-logloss:0.04276
# [45]	validation_0-logloss:0.04276
# [46]	validation_0-logloss:0.04266
# [47]	validation_0-logloss:0.04264
# [48]	validation_0-logloss:0.04262
# [49]	validation_0-logloss:0.04259
# [50]	validation_0-logloss:0.04260
# [51]	validation_0-logloss:0.04252
# [52]	validation_0-logloss:0.04250
# [53]	validation_0-logloss:0.04252
# [54]	validation_0-logloss:0.04249
# [55]	validation_0-logloss:0.04248
# [56]	validation_0-logloss:0.04248
# [57]	validation_0-logloss:0.04242
# [58]	validation_0-logloss:0.04242
# [59]	validation_0-logloss:0.04242
# [60]	validation_0-logloss:0.04242
# [61]	validation_0-logloss:0.04241
# [62]	validation_0-logloss:0.04242
# [63]	validation_0-logloss:0.04237
# [64]	validation_0-logloss:0.04235
# [65]	validation_0-logloss:0.04236
# [66]	validation_0-logloss:0.04236
# [67]	validation_0-logloss:0.04232
# [68]	validation_0-logloss:0.04231
# [69]	validation_0-logloss:0.04230
# [70]	validation_0-logloss:0.04231
# [71]	validation_0-logloss:0.04231
# [72]	validation_0-logloss:0.04232
# [73]	validation_0-logloss:0.04229
# [74]	validation_0-logloss:0.04230
# [75]	validation_0-logloss:0.04227
# [76]	validation_0-logloss:0.04228
# [77]	validation_0-logloss:0.04228
# [78]	validation_0-logloss:0.04225
# [79]	validation_0-logloss:0.04225
# [80]	validation_0-logloss:0.04220
# [81]	validation_0-logloss:0.04219
# [82]	validation_0-logloss:0.04219
# [83]	validation_0-logloss:0.04220
# [84]	validation_0-logloss:0.04218
# [85]	validation_0-logloss:0.04219
# [86]	validation_0-logloss:0.04219
# [87]	validation_0-logloss:0.04217
# [88]	validation_0-logloss:0.04217
# [89]	validation_0-logloss:0.04217
# [90]	validation_0-logloss:0.04213
# [91]	validation_0-logloss:0.04213
# [92]	validation_0-logloss:0.04213
# [93]	validation_0-logloss:0.04213
# [94]	validation_0-logloss:0.04211
# [95]	validation_0-logloss:0.04211
# [96]	validation_0-logloss:0.04210
# [97]	validation_0-logloss:0.04211
# [98]	validation_0-logloss:0.04210
# [99]	validation_0-logloss:0.04210
# [CV] END ..max_depth=2, min_child_weight=2, n_estimators=100; total time=   2.8s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=10; total time=   0.5s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=10; total time=   0.3s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=10; total time=   0.5s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=25; total time=   1.0s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=25; total time=   0.5s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04470
# [24]	validation_0-logloss:0.04447
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=25; total time=   0.5s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04292
# [42]	validation_0-logloss:0.04288
# [43]	validation_0-logloss:0.04287
# [44]	validation_0-logloss:0.04283
# [45]	validation_0-logloss:0.04274
# [46]	validation_0-logloss:0.04275
# [47]	validation_0-logloss:0.04272
# [48]	validation_0-logloss:0.04269
# [49]	validation_0-logloss:0.04268
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=50; total time=   1.3s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [25]	validation_0-logloss:0.04439
# [26]	validation_0-logloss:0.04424
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04397
# [29]	validation_0-logloss:0.04388
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04373
# [32]	validation_0-logloss:0.04355
# [33]	validation_0-logloss:0.04353
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04341
# [36]	validation_0-logloss:0.04336
# [37]	validation_0-logloss:0.04331
# [38]	validation_0-logloss:0.04317
# [39]	validation_0-logloss:0.04316
# [40]	validation_0-logloss:0.04312
# [41]	validation_0-logloss:0.04308
# [42]	validation_0-logloss:0.04298
# [43]	validation_0-logloss:0.04299
# [44]	validation_0-logloss:0.04291
# [45]	validation_0-logloss:0.04289
# [46]	validation_0-logloss:0.04285
# [47]	validation_0-logloss:0.04285
# [48]	validation_0-logloss:0.04282
# [49]	validation_0-logloss:0.04279
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=50; total time=   1.6s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04470
# [24]	validation_0-logloss:0.04447
# [25]	validation_0-logloss:0.04438
# [26]	validation_0-logloss:0.04429
# [27]	validation_0-logloss:0.04415
# [28]	validation_0-logloss:0.04387
# [29]	validation_0-logloss:0.04380
# [30]	validation_0-logloss:0.04371
# [31]	validation_0-logloss:0.04362
# [32]	validation_0-logloss:0.04354
# [33]	validation_0-logloss:0.04350
# [34]	validation_0-logloss:0.04331
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04312
# [38]	validation_0-logloss:0.04312
# [39]	validation_0-logloss:0.04311
# [40]	validation_0-logloss:0.04297
# [41]	validation_0-logloss:0.04292
# [42]	validation_0-logloss:0.04289
# [43]	validation_0-logloss:0.04286
# [44]	validation_0-logloss:0.04282
# [45]	validation_0-logloss:0.04280
# [46]	validation_0-logloss:0.04280
# [47]	validation_0-logloss:0.04271
# [48]	validation_0-logloss:0.04268
# [49]	validation_0-logloss:0.04265
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=50; total time=   0.7s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04292
# [42]	validation_0-logloss:0.04288
# [43]	validation_0-logloss:0.04287
# [44]	validation_0-logloss:0.04283
# [45]	validation_0-logloss:0.04274
# [46]	validation_0-logloss:0.04275
# [47]	validation_0-logloss:0.04272
# [48]	validation_0-logloss:0.04269
# [49]	validation_0-logloss:0.04268
# [50]	validation_0-logloss:0.04267
# [51]	validation_0-logloss:0.04261
# [52]	validation_0-logloss:0.04261
# [53]	validation_0-logloss:0.04257
# [54]	validation_0-logloss:0.04256
# [55]	validation_0-logloss:0.04257
# [56]	validation_0-logloss:0.04256
# [57]	validation_0-logloss:0.04255
# [58]	validation_0-logloss:0.04250
# [59]	validation_0-logloss:0.04251
# [60]	validation_0-logloss:0.04247
# [61]	validation_0-logloss:0.04246
# [62]	validation_0-logloss:0.04244
# [63]	validation_0-logloss:0.04244
# [64]	validation_0-logloss:0.04243
# [65]	validation_0-logloss:0.04243
# [66]	validation_0-logloss:0.04243
# [67]	validation_0-logloss:0.04244
# [68]	validation_0-logloss:0.04241
# [69]	validation_0-logloss:0.04242
# [70]	validation_0-logloss:0.04239
# [71]	validation_0-logloss:0.04240
# [72]	validation_0-logloss:0.04240
# [73]	validation_0-logloss:0.04240
# [74]	validation_0-logloss:0.04239
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=75; total time=   1.9s
# [0]	validation_0-logloss:0.14956
# [1]	validation_0-logloss:0.11977
# [2]	validation_0-logloss:0.09967
# [3]	validation_0-logloss:0.08562
# [4]	validation_0-logloss:0.07573
# [5]	validation_0-logloss:0.06834
# [6]	validation_0-logloss:0.06297
# [7]	validation_0-logloss:0.05897
# [8]	validation_0-logloss:0.05586
# [9]	validation_0-logloss:0.05380
# [10]	validation_0-logloss:0.05212
# [11]	validation_0-logloss:0.05067
# [12]	validation_0-logloss:0.04966
# [13]	validation_0-logloss:0.04890
# [14]	validation_0-logloss:0.04842
# [15]	validation_0-logloss:0.04753
# [16]	validation_0-logloss:0.04718
# [17]	validation_0-logloss:0.04654
# [18]	validation_0-logloss:0.04620
# [19]	validation_0-logloss:0.04578
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04496
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04471
# [25]	validation_0-logloss:0.04439
# [26]	validation_0-logloss:0.04424
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04397
# [29]	validation_0-logloss:0.04388
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04373
# [32]	validation_0-logloss:0.04355
# [33]	validation_0-logloss:0.04353
# [34]	validation_0-logloss:0.04344
# [35]	validation_0-logloss:0.04341
# [36]	validation_0-logloss:0.04336
# [37]	validation_0-logloss:0.04331
# [38]	validation_0-logloss:0.04317
# [39]	validation_0-logloss:0.04316
# [40]	validation_0-logloss:0.04312
# [41]	validation_0-logloss:0.04308
# [42]	validation_0-logloss:0.04298
# [43]	validation_0-logloss:0.04299
# [44]	validation_0-logloss:0.04291
# [45]	validation_0-logloss:0.04289
# [46]	validation_0-logloss:0.04285
# [47]	validation_0-logloss:0.04285
# [48]	validation_0-logloss:0.04282
# [49]	validation_0-logloss:0.04279
# [50]	validation_0-logloss:0.04277
# [51]	validation_0-logloss:0.04275
# [52]	validation_0-logloss:0.04275
# [53]	validation_0-logloss:0.04277
# [54]	validation_0-logloss:0.04269
# [55]	validation_0-logloss:0.04268
# [56]	validation_0-logloss:0.04269
# [57]	validation_0-logloss:0.04267
# [58]	validation_0-logloss:0.04267
# [59]	validation_0-logloss:0.04257
# [60]	validation_0-logloss:0.04258
# [61]	validation_0-logloss:0.04252
# [62]	validation_0-logloss:0.04252
# [63]	validation_0-logloss:0.04251
# [64]	validation_0-logloss:0.04249
# [65]	validation_0-logloss:0.04248
# [66]	validation_0-logloss:0.04244
# [67]	validation_0-logloss:0.04245
# [68]	validation_0-logloss:0.04242
# [69]	validation_0-logloss:0.04243
# [70]	validation_0-logloss:0.04242
# [71]	validation_0-logloss:0.04243
# [72]	validation_0-logloss:0.04243
# [73]	validation_0-logloss:0.04242
# [74]	validation_0-logloss:0.04243
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=75; total time=   2.4s
# [0]	validation_0-logloss:0.14950
# [1]	validation_0-logloss:0.11972
# [2]	validation_0-logloss:0.09960
# [3]	validation_0-logloss:0.08550
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06817
# [6]	validation_0-logloss:0.06284
# [7]	validation_0-logloss:0.05885
# [8]	validation_0-logloss:0.05590
# [9]	validation_0-logloss:0.05379
# [10]	validation_0-logloss:0.05195
# [11]	validation_0-logloss:0.05075
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04886
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04763
# [16]	validation_0-logloss:0.04673
# [17]	validation_0-logloss:0.04637
# [18]	validation_0-logloss:0.04607
# [19]	validation_0-logloss:0.04575
# [20]	validation_0-logloss:0.04552
# [21]	validation_0-logloss:0.04534
# [22]	validation_0-logloss:0.04490
# [23]	validation_0-logloss:0.04470
# [24]	validation_0-logloss:0.04447
# [25]	validation_0-logloss:0.04438
# [26]	validation_0-logloss:0.04429
# [27]	validation_0-logloss:0.04415
# [28]	validation_0-logloss:0.04387
# [29]	validation_0-logloss:0.04380
# [30]	validation_0-logloss:0.04371
# [31]	validation_0-logloss:0.04362
# [32]	validation_0-logloss:0.04354
# [33]	validation_0-logloss:0.04350
# [34]	validation_0-logloss:0.04331
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04312
# [38]	validation_0-logloss:0.04312
# [39]	validation_0-logloss:0.04311
# [40]	validation_0-logloss:0.04297
# [41]	validation_0-logloss:0.04292
# [42]	validation_0-logloss:0.04289
# [43]	validation_0-logloss:0.04286
# [44]	validation_0-logloss:0.04282
# [45]	validation_0-logloss:0.04280
# [46]	validation_0-logloss:0.04280
# [47]	validation_0-logloss:0.04271
# [48]	validation_0-logloss:0.04268
# [49]	validation_0-logloss:0.04265
# [50]	validation_0-logloss:0.04265
# [51]	validation_0-logloss:0.04258
# [52]	validation_0-logloss:0.04258
# [53]	validation_0-logloss:0.04257
# [54]	validation_0-logloss:0.04252
# [55]	validation_0-logloss:0.04251
# [56]	validation_0-logloss:0.04251
# [57]	validation_0-logloss:0.04242
# [58]	validation_0-logloss:0.04241
# [59]	validation_0-logloss:0.04239
# [60]	validation_0-logloss:0.04234
# [61]	validation_0-logloss:0.04235
# [62]	validation_0-logloss:0.04231
# [63]	validation_0-logloss:0.04230
# [64]	validation_0-logloss:0.04231
# [65]	validation_0-logloss:0.04232
# [66]	validation_0-logloss:0.04230
# [67]	validation_0-logloss:0.04232
# [68]	validation_0-logloss:0.04229
# [69]	validation_0-logloss:0.04229
# [70]	validation_0-logloss:0.04229
# [71]	validation_0-logloss:0.04226
# [72]	validation_0-logloss:0.04227
# [73]	validation_0-logloss:0.04227
# [74]	validation_0-logloss:0.04226
# [CV] END ...max_depth=2, min_child_weight=4, n_estimators=75; total time=   1.7s
# [0]	validation_0-logloss:0.14946
# [1]	validation_0-logloss:0.11965
# [2]	validation_0-logloss:0.09953
# [3]	validation_0-logloss:0.08542
# [4]	validation_0-logloss:0.07557
# [5]	validation_0-logloss:0.06807
# [6]	validation_0-logloss:0.06257
# [7]	validation_0-logloss:0.05866
# [8]	validation_0-logloss:0.05577
# [9]	validation_0-logloss:0.05362
# [10]	validation_0-logloss:0.05198
# [11]	validation_0-logloss:0.05058
# [12]	validation_0-logloss:0.04972
# [13]	validation_0-logloss:0.04894
# [14]	validation_0-logloss:0.04818
# [15]	validation_0-logloss:0.04771
# [16]	validation_0-logloss:0.04684
# [17]	validation_0-logloss:0.04650
# [18]	validation_0-logloss:0.04619
# [19]	validation_0-logloss:0.04581
# [20]	validation_0-logloss:0.04561
# [21]	validation_0-logloss:0.04517
# [22]	validation_0-logloss:0.04503
# [23]	validation_0-logloss:0.04479
# [24]	validation_0-logloss:0.04460
# [25]	validation_0-logloss:0.04452
# [26]	validation_0-logloss:0.04443
# [27]	validation_0-logloss:0.04410
# [28]	validation_0-logloss:0.04403
# [29]	validation_0-logloss:0.04391
# [30]	validation_0-logloss:0.04380
# [31]	validation_0-logloss:0.04367
# [32]	validation_0-logloss:0.04346
# [33]	validation_0-logloss:0.04343
# [34]	validation_0-logloss:0.04329
# [35]	validation_0-logloss:0.04325
# [36]	validation_0-logloss:0.04319
# [37]	validation_0-logloss:0.04313
# [38]	validation_0-logloss:0.04313
# [39]	validation_0-logloss:0.04299
# [40]	validation_0-logloss:0.04294
# [41]	validation_0-logloss:0.04292
# [42]	validation_0-logloss:0.04288
# [43]	validation_0-logloss:0.04287
# [44]	validation_0-logloss:0.04283
# [45]	validation_0-logloss:0.04274
# [46]	validation_0-logloss:0.04275
# [47]	validation_0-logloss:0.04272
# [48]	validation_0-logloss:0.04269
# [49]	validation_0-logloss:0.04268
# [50]	validation_0-logloss:0.04267
# [51]	validation_0-logloss:0.04261
# [52]	validation_0-logloss:0.04261
# [53]	validation_0-logloss:0.04257
# [54]	validation_0-logloss:0.04256
# [55]	validation_0-logloss:0.04257
# [56]	validation_0-logloss:0.04256
# [57]	validation_0-logloss:0.04255
# [58]	validation_0-logloss:0.04250
# [59]	validation_0-logloss:0.04251
# [60]	validation_0-logloss:0.04247
# [61]	validation_0-logloss:0.04246
# [62]	validation_0-logloss:0.04244
# [63]	validation_0-logloss:0.04244
# [64]	validation_0-logloss:0.04243
# [65]	validation_0-logloss:0.04243
# [66]	validation_0-logloss:0.04243
# [67]	validation_0-logloss:0.04244
# [68]	validation_0-logloss:0.04241
# [69]	validation_0-logloss:0.04242
# [70]	validation_0-logloss:0.04239
# [71]	validation_0-logloss:0.04240
# [72]	validation_0-logloss:0.04240
# [73]	validation_0-logloss:0.04240
# [74]	validation_0-logloss:0.04239
# [75]	validation_0-logloss:0.04240
# [76]	validation_0-logloss:0.04237
# [77]	validation_0-logloss:0.04233
# [78]	validation_0-logloss:0.04231
# [79]	validation_0-logloss:0.04229
# [80]	validation_0-logloss:0.04227
# [81]	validation_0-logloss:0.04228
# [82]	validation_0-logloss:0.04229
# [83]	validation_0-logloss:0.04228
# [84]	validation_0-logloss:0.04226
# [85]	validation_0-logloss:0.04227
# [86]	validation_0-logloss:0.04226
# [87]	validation_0-logloss:0.04227
# [88]	validation_0-logloss:0.04226
# [89]	validation_0-logloss:0.04226
# ...
# [21]	validation_0-logloss:0.04393
# [22]	validation_0-logloss:0.04387
# [23]	validation_0-logloss:0.04383
# [24]	validation_0-logloss:0.04380
# [25]	validation_0-logloss:0.04384
# [26]	validation_0-logloss:0.04380
# [27]	validation_0-logloss:0.04385
# [28]	validation_0-logloss:0.04383
# [29]	validation_0-logloss:0.04379
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04386
# [32]	validation_0-logloss:0.04389
# [33]	validation_0-logloss:0.04393
# [34]	validation_0-logloss:0.04395
# [35]	validation_0-logloss:0.04389
# [36]	validation_0-logloss:0.04396
# [37]	validation_0-logloss:0.04390
# [38]	validation_0-logloss:0.04392
# [39]	validation_0-logloss:0.04395
# [40]	validation_0-logloss:0.04394
# [41]	validation_0-logloss:0.04400
# [42]	validation_0-logloss:0.04399
# [43]	validation_0-logloss:0.04401
# [44]	validation_0-logloss:0.04403
# [45]	validation_0-logloss:0.04412
# [46]	validation_0-logloss:0.04415
# [47]	validation_0-logloss:0.04415
# [48]	validation_0-logloss:0.04415
# [49]	validation_0-logloss:0.04409
# [50]	validation_0-logloss:0.04414
# [51]	validation_0-logloss:0.04413
# [52]	validation_0-logloss:0.04416
# [53]	validation_0-logloss:0.04416
# [54]	validation_0-logloss:0.04421
# [55]	validation_0-logloss:0.04422
# [56]	validation_0-logloss:0.04421
# [57]	validation_0-logloss:0.04422
# [58]	validation_0-logloss:0.04424
# [59]	validation_0-logloss:0.04425
# [60]	validation_0-logloss:0.04423
# [61]	validation_0-logloss:0.04428
# [62]	validation_0-logloss:0.04430
# [63]	validation_0-logloss:0.04428
# [64]	validation_0-logloss:0.04429
# [65]	validation_0-logloss:0.04430
# [66]	validation_0-logloss:0.04431
# [67]	validation_0-logloss:0.04428
# [68]	validation_0-logloss:0.04430
# [69]	validation_0-logloss:0.04437
# [70]	validation_0-logloss:0.04436
# [71]	validation_0-logloss:0.04438
# [72]	validation_0-logloss:0.04437
# [73]	validation_0-logloss:0.04437
# [74]	validation_0-logloss:0.04441
# [CV] END .max_depth=10, min_child_weight=10, n_estimators=75; total time=   1.1s
# [0]	validation_0-logloss:0.14535
# [1]	validation_0-logloss:0.11516
# [2]	validation_0-logloss:0.09420
# [3]	validation_0-logloss:0.07965
# [4]	validation_0-logloss:0.06920
# [5]	validation_0-logloss:0.06189
# [6]	validation_0-logloss:0.05657
# [7]	validation_0-logloss:0.05269
# [8]	validation_0-logloss:0.04997
# [9]	validation_0-logloss:0.04795
# [10]	validation_0-logloss:0.04660
# [11]	validation_0-logloss:0.04556
# [12]	validation_0-logloss:0.04483
# [13]	validation_0-logloss:0.04428
# [14]	validation_0-logloss:0.04388
# [15]	validation_0-logloss:0.04367
# [16]	validation_0-logloss:0.04345
# [17]	validation_0-logloss:0.04333
# [18]	validation_0-logloss:0.04324
# [19]	validation_0-logloss:0.04317
# [20]	validation_0-logloss:0.04312
# [21]	validation_0-logloss:0.04311
# [22]	validation_0-logloss:0.04313
# [23]	validation_0-logloss:0.04315
# [24]	validation_0-logloss:0.04315
# [25]	validation_0-logloss:0.04316
# [26]	validation_0-logloss:0.04316
# [27]	validation_0-logloss:0.04316
# [28]	validation_0-logloss:0.04317
# [29]	validation_0-logloss:0.04318
# [30]	validation_0-logloss:0.04319
# [31]	validation_0-logloss:0.04321
# [32]	validation_0-logloss:0.04322
# [33]	validation_0-logloss:0.04325
# [34]	validation_0-logloss:0.04323
# [35]	validation_0-logloss:0.04327
# [36]	validation_0-logloss:0.04333
# [37]	validation_0-logloss:0.04332
# [38]	validation_0-logloss:0.04338
# [39]	validation_0-logloss:0.04339
# [40]	validation_0-logloss:0.04340
# [41]	validation_0-logloss:0.04338
# [42]	validation_0-logloss:0.04340
# [43]	validation_0-logloss:0.04341
# [44]	validation_0-logloss:0.04343
# [45]	validation_0-logloss:0.04343
# [46]	validation_0-logloss:0.04340
# [47]	validation_0-logloss:0.04342
# [48]	validation_0-logloss:0.04342
# [49]	validation_0-logloss:0.04341
# [50]	validation_0-logloss:0.04340
# [51]	validation_0-logloss:0.04342
# [52]	validation_0-logloss:0.04343
# [53]	validation_0-logloss:0.04343
# [54]	validation_0-logloss:0.04347
# [55]	validation_0-logloss:0.04349
# [56]	validation_0-logloss:0.04350
# [57]	validation_0-logloss:0.04351
# [58]	validation_0-logloss:0.04351
# [59]	validation_0-logloss:0.04351
# [60]	validation_0-logloss:0.04351
# [61]	validation_0-logloss:0.04353
# [62]	validation_0-logloss:0.04353
# [63]	validation_0-logloss:0.04353
# [64]	validation_0-logloss:0.04356
# [65]	validation_0-logloss:0.04357
# [66]	validation_0-logloss:0.04359
# [67]	validation_0-logloss:0.04361
# [68]	validation_0-logloss:0.04361
# [69]	validation_0-logloss:0.04361
# [70]	validation_0-logloss:0.04361
# [71]	validation_0-logloss:0.04361
# [72]	validation_0-logloss:0.04365
# [73]	validation_0-logloss:0.04364
# [74]	validation_0-logloss:0.04364
# [CV] END .max_depth=10, min_child_weight=10, n_estimators=75; total time=   0.9s
# [0]	validation_0-logloss:0.14543
# [1]	validation_0-logloss:0.11522
# [2]	validation_0-logloss:0.09458
# [3]	validation_0-logloss:0.07993
# [4]	validation_0-logloss:0.06951
# [5]	validation_0-logloss:0.06207
# [6]	validation_0-logloss:0.05683
# [7]	validation_0-logloss:0.05298
# [8]	validation_0-logloss:0.05030
# [9]	validation_0-logloss:0.04829
# [10]	validation_0-logloss:0.04684
# [11]	validation_0-logloss:0.04582
# [12]	validation_0-logloss:0.04504
# [13]	validation_0-logloss:0.04456
# [14]	validation_0-logloss:0.04428
# [15]	validation_0-logloss:0.04397
# [16]	validation_0-logloss:0.04380
# [17]	validation_0-logloss:0.04367
# [18]	validation_0-logloss:0.04356
# [19]	validation_0-logloss:0.04345
# [20]	validation_0-logloss:0.04345
# [21]	validation_0-logloss:0.04346
# [22]	validation_0-logloss:0.04344
# [23]	validation_0-logloss:0.04352
# [24]	validation_0-logloss:0.04353
# [25]	validation_0-logloss:0.04352
# [26]	validation_0-logloss:0.04351
# [27]	validation_0-logloss:0.04352
# [28]	validation_0-logloss:0.04354
# [29]	validation_0-logloss:0.04361
# [30]	validation_0-logloss:0.04357
# [31]	validation_0-logloss:0.04364
# [32]	validation_0-logloss:0.04358
# [33]	validation_0-logloss:0.04361
# [34]	validation_0-logloss:0.04357
# [35]	validation_0-logloss:0.04355
# [36]	validation_0-logloss:0.04359
# [37]	validation_0-logloss:0.04358
# [38]	validation_0-logloss:0.04362
# [39]	validation_0-logloss:0.04364
# [40]	validation_0-logloss:0.04365
# [41]	validation_0-logloss:0.04362
# [42]	validation_0-logloss:0.04365
# [43]	validation_0-logloss:0.04366
# [44]	validation_0-logloss:0.04368
# [45]	validation_0-logloss:0.04365
# [46]	validation_0-logloss:0.04366
# [47]	validation_0-logloss:0.04367
# [48]	validation_0-logloss:0.04373
# [49]	validation_0-logloss:0.04369
# [50]	validation_0-logloss:0.04376
# [51]	validation_0-logloss:0.04380
# [52]	validation_0-logloss:0.04378
# [53]	validation_0-logloss:0.04383
# [54]	validation_0-logloss:0.04381
# [55]	validation_0-logloss:0.04382
# [56]	validation_0-logloss:0.04384
# [57]	validation_0-logloss:0.04385
# [58]	validation_0-logloss:0.04386
# [59]	validation_0-logloss:0.04388
# [60]	validation_0-logloss:0.04389
# [61]	validation_0-logloss:0.04391
# [62]	validation_0-logloss:0.04391
# [63]	validation_0-logloss:0.04390
# [64]	validation_0-logloss:0.04395
# [65]	validation_0-logloss:0.04394
# [66]	validation_0-logloss:0.04394
# [67]	validation_0-logloss:0.04397
# [68]	validation_0-logloss:0.04398
# [69]	validation_0-logloss:0.04398
# [70]	validation_0-logloss:0.04398
# [71]	validation_0-logloss:0.04401
# [72]	validation_0-logloss:0.04402
# [73]	validation_0-logloss:0.04405
# [74]	validation_0-logloss:0.04404
# [75]	validation_0-logloss:0.04408
# [76]	validation_0-logloss:0.04409
# [77]	validation_0-logloss:0.04407
# [78]	validation_0-logloss:0.04407
# [79]	validation_0-logloss:0.04410
# [80]	validation_0-logloss:0.04410
# [81]	validation_0-logloss:0.04411
# [82]	validation_0-logloss:0.04412
# [83]	validation_0-logloss:0.04411
# [84]	validation_0-logloss:0.04413
# [85]	validation_0-logloss:0.04414
# [86]	validation_0-logloss:0.04413
# [87]	validation_0-logloss:0.04415
# [88]	validation_0-logloss:0.04413
# [89]	validation_0-logloss:0.04418
# [90]	validation_0-logloss:0.04418
# [91]	validation_0-logloss:0.04420
# [92]	validation_0-logloss:0.04421
# [93]	validation_0-logloss:0.04422
# [94]	validation_0-logloss:0.04422
# [95]	validation_0-logloss:0.04424
# [96]	validation_0-logloss:0.04423
# [97]	validation_0-logloss:0.04425
# [98]	validation_0-logloss:0.04424
# [99]	validation_0-logloss:0.04425
# [CV] END max_depth=10, min_child_weight=10, n_estimators=100; total time=   1.0s
# [0]	validation_0-logloss:0.14558
# [1]	validation_0-logloss:0.11514
# [2]	validation_0-logloss:0.09438
# [3]	validation_0-logloss:0.07999
# [4]	validation_0-logloss:0.06975
# [5]	validation_0-logloss:0.06237
# [6]	validation_0-logloss:0.05712
# [7]	validation_0-logloss:0.05336
# [8]	validation_0-logloss:0.05070
# [9]	validation_0-logloss:0.04872
# [10]	validation_0-logloss:0.04731
# [11]	validation_0-logloss:0.04628
# [12]	validation_0-logloss:0.04553
# [13]	validation_0-logloss:0.04504
# [14]	validation_0-logloss:0.04468
# [15]	validation_0-logloss:0.04444
# [16]	validation_0-logloss:0.04428
# [17]	validation_0-logloss:0.04416
# [18]	validation_0-logloss:0.04409
# [19]	validation_0-logloss:0.04400
# [20]	validation_0-logloss:0.04396
# [21]	validation_0-logloss:0.04393
# [22]	validation_0-logloss:0.04387
# [23]	validation_0-logloss:0.04383
# [24]	validation_0-logloss:0.04380
# [25]	validation_0-logloss:0.04384
# [26]	validation_0-logloss:0.04380
# [27]	validation_0-logloss:0.04385
# [28]	validation_0-logloss:0.04383
# [29]	validation_0-logloss:0.04379
# [30]	validation_0-logloss:0.04383
# [31]	validation_0-logloss:0.04386
# [32]	validation_0-logloss:0.04389
# [33]	validation_0-logloss:0.04393
# [34]	validation_0-logloss:0.04395
# [35]	validation_0-logloss:0.04389
# [36]	validation_0-logloss:0.04396
# [37]	validation_0-logloss:0.04390
# [38]	validation_0-logloss:0.04392
# [39]	validation_0-logloss:0.04395
# [40]	validation_0-logloss:0.04394
# [41]	validation_0-logloss:0.04400
# [42]	validation_0-logloss:0.04399
# [43]	validation_0-logloss:0.04401
# [44]	validation_0-logloss:0.04403
# [45]	validation_0-logloss:0.04412
# [46]	validation_0-logloss:0.04415
# [47]	validation_0-logloss:0.04415
# [48]	validation_0-logloss:0.04415
# [49]	validation_0-logloss:0.04409
# [50]	validation_0-logloss:0.04414
# [51]	validation_0-logloss:0.04413
# [52]	validation_0-logloss:0.04416
# [53]	validation_0-logloss:0.04416
# [54]	validation_0-logloss:0.04421
# [55]	validation_0-logloss:0.04422
# [56]	validation_0-logloss:0.04421
# [57]	validation_0-logloss:0.04422
# [58]	validation_0-logloss:0.04424
# [59]	validation_0-logloss:0.04425
# [60]	validation_0-logloss:0.04423
# [61]	validation_0-logloss:0.04428
# [62]	validation_0-logloss:0.04430
# [63]	validation_0-logloss:0.04428
# [64]	validation_0-logloss:0.04429
# [65]	validation_0-logloss:0.04430
# [66]	validation_0-logloss:0.04431
# [67]	validation_0-logloss:0.04428
# [68]	validation_0-logloss:0.04430
# [69]	validation_0-logloss:0.04437
# [70]	validation_0-logloss:0.04436
# [71]	validation_0-logloss:0.04438
# [72]	validation_0-logloss:0.04437
# [73]	validation_0-logloss:0.04437
# [74]	validation_0-logloss:0.04441
# [75]	validation_0-logloss:0.04441
# [76]	validation_0-logloss:0.04444
# [77]	validation_0-logloss:0.04441
# [78]	validation_0-logloss:0.04445
# [79]	validation_0-logloss:0.04442
# [80]	validation_0-logloss:0.04445
# [81]	validation_0-logloss:0.04444
# [82]	validation_0-logloss:0.04448
# [83]	validation_0-logloss:0.04448
# [84]	validation_0-logloss:0.04449
# [85]	validation_0-logloss:0.04453
# [86]	validation_0-logloss:0.04456
# [87]	validation_0-logloss:0.04454
# [88]	validation_0-logloss:0.04455
# [89]	validation_0-logloss:0.04455
# [90]	validation_0-logloss:0.04460
# [91]	validation_0-logloss:0.04458
# [92]	validation_0-logloss:0.04457
# [93]	validation_0-logloss:0.04461
# [94]	validation_0-logloss:0.04465
# [95]	validation_0-logloss:0.04466
# [96]	validation_0-logloss:0.04468
# [97]	validation_0-logloss:0.04467
# [98]	validation_0-logloss:0.04467
# [99]	validation_0-logloss:0.04471
# [CV] END max_depth=10, min_child_weight=10, n_estimators=100; total time=   1.3s
# [0]	validation_0-logloss:0.14535
# [1]	validation_0-logloss:0.11516
# [2]	validation_0-logloss:0.09420
# [3]	validation_0-logloss:0.07965
# [4]	validation_0-logloss:0.06920
# [5]	validation_0-logloss:0.06189
# [6]	validation_0-logloss:0.05657
# [7]	validation_0-logloss:0.05269
# [8]	validation_0-logloss:0.04997
# [9]	validation_0-logloss:0.04795
# [10]	validation_0-logloss:0.04660
# [11]	validation_0-logloss:0.04556
# [12]	validation_0-logloss:0.04483
# [13]	validation_0-logloss:0.04428
# [14]	validation_0-logloss:0.04388
# [15]	validation_0-logloss:0.04367
# [16]	validation_0-logloss:0.04345
# [17]	validation_0-logloss:0.04333
# [18]	validation_0-logloss:0.04324
# [19]	validation_0-logloss:0.04317
# [20]	validation_0-logloss:0.04312
# [21]	validation_0-logloss:0.04311
# [22]	validation_0-logloss:0.04313
# [23]	validation_0-logloss:0.04315
# [24]	validation_0-logloss:0.04315
# [25]	validation_0-logloss:0.04316
# [26]	validation_0-logloss:0.04316
# [27]	validation_0-logloss:0.04316
# [28]	validation_0-logloss:0.04317
# [29]	validation_0-logloss:0.04318
# [30]	validation_0-logloss:0.04319
# [31]	validation_0-logloss:0.04321
# [32]	validation_0-logloss:0.04322
# [33]	validation_0-logloss:0.04325
# [34]	validation_0-logloss:0.04323
# [35]	validation_0-logloss:0.04327
# [36]	validation_0-logloss:0.04333
# [37]	validation_0-logloss:0.04332
# [38]	validation_0-logloss:0.04338
# [39]	validation_0-logloss:0.04339
# [40]	validation_0-logloss:0.04340
# [41]	validation_0-logloss:0.04338
# [42]	validation_0-logloss:0.04340
# [43]	validation_0-logloss:0.04341
# [44]	validation_0-logloss:0.04343
# [45]	validation_0-logloss:0.04343
# [46]	validation_0-logloss:0.04340
# [47]	validation_0-logloss:0.04342
# [48]	validation_0-logloss:0.04342
# [49]	validation_0-logloss:0.04341
# [50]	validation_0-logloss:0.04340
# [51]	validation_0-logloss:0.04342
# [52]	validation_0-logloss:0.04343
# [53]	validation_0-logloss:0.04343
# [54]	validation_0-logloss:0.04347
# [55]	validation_0-logloss:0.04349
# [56]	validation_0-logloss:0.04350
# [57]	validation_0-logloss:0.04351
# [58]	validation_0-logloss:0.04351
# [59]	validation_0-logloss:0.04351
# [60]	validation_0-logloss:0.04351
# [61]	validation_0-logloss:0.04353
# [62]	validation_0-logloss:0.04353
# [63]	validation_0-logloss:0.04353
# [64]	validation_0-logloss:0.04356
# [65]	validation_0-logloss:0.04357
# [66]	validation_0-logloss:0.04359
# [67]	validation_0-logloss:0.04361
# [68]	validation_0-logloss:0.04361
# [69]	validation_0-logloss:0.04361
# [70]	validation_0-logloss:0.04361
# [71]	validation_0-logloss:0.04361
# [72]	validation_0-logloss:0.04365
# [73]	validation_0-logloss:0.04364
# [74]	validation_0-logloss:0.04364
# [75]	validation_0-logloss:0.04366
# [76]	validation_0-logloss:0.04372
# [77]	validation_0-logloss:0.04376
# [78]	validation_0-logloss:0.04378
# [79]	validation_0-logloss:0.04387
# [80]	validation_0-logloss:0.04389
# [81]	validation_0-logloss:0.04389
# [82]	validation_0-logloss:0.04389
# [83]	validation_0-logloss:0.04390
# [84]	validation_0-logloss:0.04391
# [85]	validation_0-logloss:0.04391
# [86]	validation_0-logloss:0.04391
# [87]	validation_0-logloss:0.04390
# [88]	validation_0-logloss:0.04391
# [89]	validation_0-logloss:0.04393
# [90]	validation_0-logloss:0.04394
# [91]	validation_0-logloss:0.04394
# [92]	validation_0-logloss:0.04394
# [93]	validation_0-logloss:0.04395
# [94]	validation_0-logloss:0.04394
# [95]	validation_0-logloss:0.04394
# [96]	validation_0-logloss:0.04394
# [97]	validation_0-logloss:0.04394
# [98]	validation_0-logloss:0.04395
# [99]	validation_0-logloss:0.04396
# [CV] END max_depth=10, min_child_weight=10, n_estimators=100; total time=   1.1s
# [0]	validation_0-logloss:0.14547
# [1]	validation_0-logloss:0.11544
# [2]	validation_0-logloss:0.09496
# [3]	validation_0-logloss:0.08036
# [4]	validation_0-logloss:0.07003
# [5]	validation_0-logloss:0.06246
# [6]	validation_0-logloss:0.05711
# [7]	validation_0-logloss:0.05304
# [8]	validation_0-logloss:0.05032
# [9]	validation_0-logloss:0.04826
# [10]	validation_0-logloss:0.04661
# [11]	validation_0-logloss:0.04546
# [12]	validation_0-logloss:0.04467
# [13]	validation_0-logloss:0.04411
# [14]	validation_0-logloss:0.04367
# [15]	validation_0-logloss:0.04338
# [16]	validation_0-logloss:0.04309
# [17]	validation_0-logloss:0.04292
# [18]	validation_0-logloss:0.04284
# [19]	validation_0-logloss:0.04270
# [20]	validation_0-logloss:0.04265
# [21]	validation_0-logloss:0.04257
# [22]	validation_0-logloss:0.04256
# [23]	validation_0-logloss:0.04253
# [24]	validation_0-logloss:0.04250
# Best Parameters: {'max_depth': 6, 'min_child_weight': 8, 'n_estimators': 25}
# Best Score: 0.7937945089953323
# f1-score on train set :  0.7727474760302242
# f1-score on test set :  0.7680000000000001

# %% [markdown]
# # Submission to the leaderboard of the best models

# %%
X = np.append(X_train, X_test, axis=0)
Y = np.append(Y_train, Y_test)

logreg = LogisticRegressionCV(Cs=10, penalty='l2').fit(X,Y)
RFC = RandomForestClassifier(max_depth=10, min_samples_leaf=10, 
                    min_samples_split=20, n_estimators=50).fit(X,Y)
XGBC = XGBClassifier(max_depth=2, min_child_weight=8, n_estimators=25).fit(X,Y)
voting.fit(X,Y)

sm = SMOTENC(categorical_features=[2,3,4,5,6,7], sampling_strategy=0.05)
X_resampled, Y_resampled = sm.fit_resample(X, Y)
xgbc_smote = XGBClassifier(max_depth=6, min_child_weight=8, n_estimators=25).fit(X_resampled, Y_resampled)

# Read data without labels
data_without_labels = pd.read_csv('conversion_data_test.csv')
print('Prediction set (without labels):', data_without_labels.shape)

# Warning : check consistency of features_list (must be the same as the features 
# used by your best classifier)
#features_list = ['total_pages_visited']
X_without_labels = data_without_labels.loc[:, features_list]

# Convert pandas DataFrames to arrays before using scikit-learn
print("Convert pandas DataFrames to arrays...")
#X_without_labels = X_without_labels.values
print("...Done")

#print(X_without_labels[0:5,:])
print(X_without_labels.head())

# WARNING : PUT HERE THE SAME PREPROCESSING AS FOR YOUR TEST SET
# CHECK YOU ARE USING X_without_labels
print("Encoding categorical features and standardizing numerical features...")

X_without_labels = preprocessor.transform(X_without_labels)
print("...Done")
print(X_without_labels[0:5,:])

data = {
    'converted': logreg.predict(X_without_labels)
}
Y_predictions = pd.DataFrame(columns=['converted'],data=data)
Y_predictions.to_csv('conversion_data_test_predictions_EUGENIE-logreg.csv', index=False)
data = {
    'converted': RFC.predict(X_without_labels)
}
Y_predictions = pd.DataFrame(columns=['converted'],data=data)
Y_predictions.to_csv('conversion_data_test_predictions_EUGENIE-RFC.csv', index=False)
data = {
    'converted': XGBC.predict(X_without_labels)
}
Y_predictions = pd.DataFrame(columns=['converted'],data=data)
Y_predictions.to_csv('conversion_data_test_predictions_EUGENIE-XGBC.csv', index=False)
data = {
    'converted': voting.predict(X_without_labels)
}
Y_predictions = pd.DataFrame(columns=['converted'],data=data)
Y_predictions.to_csv('conversion_data_test_predictions_EUGENIE-voting.csv', index=False)
data = {
    'converted': xgbc_smote.predict(X_without_labels)
}
Y_predictions = pd.DataFrame(columns=['converted'],data=data)
Y_predictions.to_csv('conversion_data_test_predictions_EUGENIE-xgbc_smote.csv', index=False)
# Out:
# Prediction set (without labels): (31620, 5)
# Convert pandas DataFrames to arrays...
# ...Done
#   country  age  new_user  source  total_pages_visited
# 0      UK   28         0     Seo                   16
# 1      UK   22         1  Direct                    5
# 2   China   32         1     Seo                    1
# 3      US   32         1     Ads                    6
# 4   China   25         0     Seo                    3
# Encoding categorical features and standardizing numerical features...
# ...Done
# [[-0.31000438  3.33049128  0.          1.          0.          0.
#    0.          1.        ]
#  [-1.03592414  0.03829244  0.          1.          0.          1.
#    1.          0.        ]
#  [ 0.17394213 -1.15887077  0.          0.          0.          1.
#    0.          1.        ]
#  [ 0.17394213  0.33758325  0.          0.          1.          1.
#    0.          0.        ]
#  [-0.67296426 -0.56028917  0.          0.          0.          0.
#    0.          1.        ]]

# %% [markdown]
# Conclusion : the best model is the Logistic Regression

# %% [markdown]
# # Conclusions

# %%
logreg = LogisticRegressionCV(Cs=10, penalty='l2') 
logreg.fit(X_train, Y_train)

Y_train_pred = logreg.predict(X_train)
Y_test_pred = logreg.predict(X_test)

# %%
# confusion matrixes for the best model

_, ax = plt.subplots()
ax.set(
    title="Confusion Matrix on Train set"
)  
ConfusionMatrixDisplay.from_estimator(
    logreg, 
    X_train, Y_train, ax=ax
) 
plt.show()

_, ax = plt.subplots() 
ax.set(
    title="Confusion Matrix on Test set"
)  
ConfusionMatrixDisplay.from_estimator(
    logreg, 
    X_test, Y_test, ax=ax
)  
plt.show()

# %%
# classification report for the best model

print(classification_report(Y_test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     27710
#            1       0.70      0.86      0.77       748
#
#     accuracy                           0.99     28458
#    macro avg       0.85      0.92      0.88     28458
# weighted avg       0.99      0.99      0.99     28458

# %%
# ROC curve

fpr, tpr, _ = roc_curve(Y_test, Y_test_pred, pos_label=logreg.classes_[1])
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Analysing the best model's parameters

column_names = []
for name, pipeline, features_list in preprocessor.transformers_: 
    if name == 'num': 
        features = features_list 
    else: 
        features = pipeline.get_feature_names_out()   
    column_names.extend(features) 
        
coefs = pd.DataFrame(index = column_names, data = logreg.coef_.transpose(), columns=["coefficients"])
feature_importance = coefs.sort_values(by = 'coefficients', key=abs)

fig = px.bar(feature_importance, orientation = 'h')
fig.update_layout(showlegend = False, 
                  margin = {'l': 120}, title_x=0.5,
                  title_text="Features importance of the best model (Logistic Regression with Ridge)"
                 )
fig.show()

# %% [markdown]
# Perpectives :
# - tester les modèles en appliquant un threshold pour le choix de la labellisation, qui ne soit pas 0.5 (valeur par défaut)
